# %%
epochs12_gpu_local = 133 #12 epochs took 113 seconds on local machine using GPU
epochs12_gpu_colab = 885 #12 epochs took 885 seconds on google colab using GPU
epochs12_tpu = 167 #12 epochs took 885 seconds using TPU and google cloud services for storage, TPU etc.

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
y_axis = [133,885,167]
x_axis =["Local GPU","GPU Colab","TPU"]
ax.bar(x_axis, y_axis)
plt.title("Time Taken for Training 12 Epochs Each (in seconds)")
plt.show()

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
y_axis = [40,599,68]
x_axis =["Local GPU","GPU Colab","TPU"]
ax.bar(x_axis, y_axis)
plt.title("Time Taken for Training First Epoch (in seconds)")
plt.show()

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
y_axis = [11,26,9]
x_axis =["Local GPU","GPU Colab","TPU"]
ax.bar(x_axis, y_axis)
plt.title("Time Taken for Training Second Epoch (in seconds)")
plt.show()
